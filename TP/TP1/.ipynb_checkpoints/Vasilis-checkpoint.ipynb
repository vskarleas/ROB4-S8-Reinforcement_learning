# %% [markdown]
#  Copyright © Sorbonne University.
#
#  This source code is licensed under the MIT license found in the LICENSE file
#  in the root directory of this source tree.

# %% [markdown]
# **Students:** Rami Aridi, Vasilis Skarleas

# %% [markdown]
# # Overview
#
# In this notebook, we study the **value iteration** and **policy
# iteration** algorithms in a maze environment.

# %% [markdown]
# # Installation

# %%
import sys
import subprocess

def install_package(package):
    """Installs a package inside the active virtual environment."""
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])
    
# Install box2d-py now that SWIG is installed
install_package("box2d-py")

# Ensure required packages are installed
required_packages = ["easypip", "moviepy", "bbrl>=0.2.2", "tensorboard", "swig", "box2d-py", "bbrl_utils"]
for package in required_packages:
    install_package(package)

# Import modules after ensuring installation
from easypip import easyimport, easyinstall, is_notebook
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from typing import List, Tuple

# Ensure `moviepy` is available before importing
try:
    from moviepy.editor import ipython_display as video_display
except ModuleNotFoundError:
    install_package("moviepy")
    from moviepy.editor import ipython_display as video_display

# Ensure correct behavior in non-notebook environments
if not is_notebook():
    print("Not displaying video (hidden since not in a notebook)", file=sys.stderr)
    def video_display(*args, **kwargs):
        pass
    def display(*args, **kwargs):
        print(*args, **kwargs)

# Import other dependencies
import gymnasium as gym
easyimport("bbrl_utils").setup(maze_mdp=True)
from bbrl_gymnasium.envs.maze_mdp import MazeMDPEnv
from mazemdp.mdp import Mdp
from mazemdp.toolbox import egreedy, egreedy_loc, sample_categorical, softmax
from mazemdp import random_policy
# Out:
# Requirement already satisfied: box2d-py in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (2.3.8)
# Requirement already satisfied: easypip in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (1.3.5)
# Requirement already satisfied: packaging in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from easypip) (24.2)
# Requirement already satisfied: moviepy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (2.2.2)
# Requirement already satisfied: proglog<=1.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (1.0.1)
# Requirement already satisfied: pillow<11.0,>=9.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy) (10.4.0)
# Requirement already satisfied: tqdm in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy) (4.67.1)
# Requirement already satisfied: bbrl>=0.2.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (0.3.3)
# Requirement already satisfied: torch>=1.9.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.6.0)
# Requirement already satisfied: torchvision in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (0.21.0)
# Requirement already satisfied: tensorboard in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.18.0)
# Requirement already satisfied: tqdm in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (4.67.1)
# Requirement already satisfied: hydra-core in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (1.3.2)
# Requirement already satisfied: numpy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.2.2)
# Requirement already satisfied: pandas in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.2.3)
# Requirement already satisfied: opencv-python in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (4.11.0.86)
# Requirement already satisfied: omegaconf in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.3.0)
# Requirement already satisfied: matplotlib in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (3.10.0)
# Requirement already satisfied: seaborn in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (0.13.2)
# Requirement already satisfied: scipy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (1.15.1)
# Requirement already satisfied: bootstrapped in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (0.0.2)
# Requirement already satisfied: gymnasium in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (1.0.0)
# Requirement already satisfied: moviepy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.2.2) (2.1.2)
# Requirement already satisfied: filelock in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (4.12.2)
# Requirement already satisfied: networkx in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (3.1.5)
# Requirement already satisfied: fsspec in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (2025.2.0)
# Requirement already satisfied: setuptools in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.9.0->bbrl>=0.2.2) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from pandas->bbrl>=0.2.2) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from pandas->bbrl>=0.2.2) (2025.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium->bbrl>=0.2.2) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium->bbrl>=0.2.2) (0.0.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from hydra-core->bbrl>=0.2.2) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from omegaconf->bbrl>=0.2.2) (6.0.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.2.2) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.2.2) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.2.2) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.2.2) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.2.2) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (5.29.3)
# Requirement already satisfied: six>1.9 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl>=0.2.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->bbrl>=0.2.2) (3.0.2)
# Requirement already satisfied: tensorboard in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (2.2.2)
# Requirement already satisfied: packaging in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (75.8.0)
# Requirement already satisfied: six>1.9 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: swig in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (4.3.0)
# Requirement already satisfied: box2d-py in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (2.3.8)
# Collecting bbrl_utils
#   Using cached bbrl_utils-0.10.3-py3-none-any.whl.metadata (443 bytes)
# Requirement already satisfied: easypip in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl_utils) (1.3.5)
# Requirement already satisfied: bbrl>=0.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl_utils) (0.3.3)
# Collecting bbrl-gymnasium>=0.3.5 (from bbrl_utils)
#   Using cached bbrl_gymnasium-0.3.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tensorboard in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl_utils) (2.18.0)
# Collecting pygame (from bbrl_utils)
#   Using cached pygame-2.6.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: torch>=1.9.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (2.6.0)
# Requirement already satisfied: torchvision in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (0.21.0)
# Requirement already satisfied: tqdm in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (4.67.1)
# Requirement already satisfied: hydra-core in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (1.3.2)
# Requirement already satisfied: numpy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (2.2.2)
# Requirement already satisfied: pandas in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (2.2.3)
# Requirement already satisfied: opencv-python in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (4.11.0.86)
# Requirement already satisfied: omegaconf in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (2.3.0)
# Requirement already satisfied: matplotlib in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (3.10.0)
# Requirement already satisfied: seaborn in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (0.13.2)
# Requirement already satisfied: scipy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (1.15.1)
# Requirement already satisfied: bootstrapped in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (0.0.2)
# Requirement already satisfied: gymnasium in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (1.0.0)
# Requirement already satisfied: moviepy in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from bbrl>=0.3.1->bbrl_utils) (2.1.2)
# Collecting gymnasium (from bbrl>=0.3.1->bbrl_utils)
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting mazemdp>=1.2.0 (from bbrl-gymnasium>=0.3.5->bbrl_utils)
#   Using cached mazemdp-1.2.10-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: packaging in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from easypip->bbrl_utils) (24.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (75.8.0)
# Requirement already satisfied: six>1.9 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from tensorboard->bbrl_utils) (3.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium->bbrl>=0.3.1->bbrl_utils) (0.0.4)
# Collecting ipyreact (from mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils)
#   Using cached ipyreact-0.5.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.17.0)
# Requirement already satisfied: networkx in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (3.1.5)
# Requirement already satisfied: fsspec in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (2025.2.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.9.0->bbrl>=0.3.1->bbrl_utils) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->bbrl_utils) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from matplotlib->bbrl>=0.3.1->bbrl_utils) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from pandas->bbrl>=0.3.1->bbrl_utils) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from pandas->bbrl>=0.3.1->bbrl_utils) (2025.1)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d]->bbrl-gymnasium>=0.3.5->bbrl_utils)
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: swig==4.* in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from gymnasium[box2d]->bbrl-gymnasium>=0.3.5->bbrl_utils) (4.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from hydra-core->bbrl>=0.3.1->bbrl_utils) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from omegaconf->bbrl>=0.3.1->bbrl_utils) (6.0.2)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from moviepy->bbrl>=0.3.1->bbrl_utils) (1.0.1)
# Collecting anywidget>=0.2.0 (from ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils)
#   Using cached anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (8.1.5)
# Collecting psygnal>=0.8.1 (from anywidget>=0.2.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils)
#   Using cached psygnal-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (8.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.13)
# Requirement already satisfied: jedi>=0.16 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (2.19.1)
# Requirement already satisfied: stack_data in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact->mazemdp>=1.2.0->bbrl-gymnasium>=0.3.5->bbrl_utils) (0.2.3)
# Using cached bbrl_utils-0.10.3-py3-none-any.whl (11 kB)
# Using cached bbrl_gymnasium-0.3.9-py3-none-any.whl (27 kB)
# Using cached pygame-2.6.1-cp312-cp312-macosx_11_0_arm64.whl (12.4 MB)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Using cached mazemdp-1.2.10-py3-none-any.whl (18 kB)
# Using cached ipyreact-0.5.0-py3-none-any.whl (1.8 MB)
# Using cached anywidget-0.9.13-py3-none-any.whl (213 kB)
# Using cached psygnal-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (426 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (pyproject.toml): started
#   Building wheel for box2d-py (pyproject.toml): finished with status 'error'
# Failed to build box2d-py
#   error: subprocess-exited-with-error
#
#   × Building wheel for box2d-py (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Using setuptools (version 75.8.0).
#       /private/var/folders/t_/frzm_2tj29v28m53gb74jjj00000gn/T/pip-build-env-ke6xo3am/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py:270: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.9-universal2-cpython-312/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.macosx-10.9-universal2-cpython-312/Box2D
#       copying library/Box2D/__init__.py -> build/lib.macosx-10.9-universal2-cpython-312/Box2D
#       creating build/lib.macosx-10.9-universal2-cpython-312/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.macosx-10.9-universal2-cpython-312/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       Traceback (most recent call last):
#         File "/Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/bin/swig", line 7, in <module>
#           from swig import swig
#       ModuleNotFoundError: No module named 'swig'
#       error: command '/Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/bin/swig' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (box2d-py)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 14
#      12 required_packages = ["easypip", "moviepy", "bbrl>=0.2.2", "tensorboard", "swig", "box2d-py", "bbrl_utils"]
#      13 for package in required_packages:
# ---> 14     install_package(package)
#      16 # Import modules after ensuring installation
#      17 from easypip import easyimport, easyinstall, is_notebook
#
# Cell In[2], line 6, in install_package(package)
#       4 def install_package(package):
#       5     """Installs a package inside the active virtual environment."""
# ----> 6     subprocess.check_call([sys.executable, "-m", "pip", "install", package])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:413, in check_call(*popenargs, **kwargs)
#     411     if cmd is None:
#     412         cmd = popenargs[0]
# --> 413     raise CalledProcessError(retcode, cmd)
#     414 return 0
#
# CalledProcessError: Command '['/Users/vasilisskarleas/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/env-reinforcement-learning/bin/python', '-m', 'pip', 'install', 'bbrl_utils']' returned non-zero exit status 1.

# %% [markdown]
# # Agents and MDPs
#
# A reinforcement learning agent interacts with an environment represented as a
# Markov Decision Process (MDP). It is defined by a tuple $(S, A, P, r, \gamma)$
# where $S$ is the state space, $A$ is the action space, $P(state_t, action_t,
# state_{t+1})$ is the transition function, $r(state_t, action_t)$ is the reward
# function and $\gamma \in [0, 1]$ is the discount factor.
#
# In what follows we import code to create an MDP corresponding to a random maze
# (see https://github.com/osigaud/SimpleMazeMDP for documentation).

# %%
env = gym.make(
    "MazeMDP-v0",
    kwargs={"width": 5, "height": 5, "ratio": 0.2},
    render_mode="human",
)
env = env.unwrapped
env.reset()

# in dynamic programming, there is no agent moving in the environment
env.set_no_agent()
env.init_draw("The maze")
# Out:
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 env = gym.make(
#       2     "MazeMDP-v0",
#       3     kwargs={"width": 5, "height": 5, "ratio": 0.2},
#       4     render_mode="human",
#       5 )
#       6 env = env.unwrapped
#       7 env.reset()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:687, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     684     assert isinstance(id, str)
#     686     # The environment name can include an unloaded module in "module:env_name" style
# --> 687     env_spec = _find_spec(id)
#     689 assert isinstance(env_spec, EnvSpec)
#     691 # Update the env spec kwargs with the `make` kwargs
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:531, in _find_spec(env_id)
#     525     logger.warn(
#     526         f"Using the latest versioned environment `{new_env_id}` "
#     527         f"instead of the unversioned environment `{env_name}`."
#     528     )
#     530 if env_spec is None:
# --> 531     _check_version_exists(ns, name, version)
#     532     raise error.Error(
#     533         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     534     )
#     536 return env_spec
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:397, in _check_version_exists(ns, name, version)
#     394 if get_env_id(ns, name, version) in registry:
#     395     return
# --> 397 _check_name_exists(ns, name)
#     398 if version is None:
#     399     return
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/University Sorbonne/4th year/S8/Reinforcement learning/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:374, in _check_name_exists(ns, name)
#     371 namespace_msg = f" in namespace {ns}" if ns else ""
#     372 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 374 raise error.NameNotFound(
#     375     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     376 )
#
# NameNotFound: Environment `MazeMDP` doesn't exist.

# %% [markdown]
# **Dynamic programming**
#
# The goal of an RL agent is to find the optimal behaviour, defined by a policy
# $\pi$ that assigns an action (or distribution over actions) to each state so
# as to maximize the agent's total expected reward. In order to estimate how
# good a state is, either a state value function $V(x)$ or a state-action value
# function $Q(x,u)$ is used.
#
# Dynamic programming algorithms are used for planning, **they require a full**
# **knowledge of the MDP from the agent** (in contrast to "true" RL where the agent
# does not know the transition and reward functions). They find the optimal
# policy by computing a value function $V$ or an action-value function $Q$ over
# the state space or state-action space of the given MDP. **Value iteration**
# and **policy iteration** are two standard dynamic programming algorithms. You
# should study both of them using both $V$ and $Q$, as these algorithms contain
# the basic building blocks for most RL algorithms.
#
# # Value Iteration
#
# ## Value Iteration with the V function
#
# When using the $V$ function, **value iteration** aims at finding the optimal
# values $V^*$ based on the Bellman Optimality Equation: $$V^*(s) = \max_a
# \big[r(s,a) + \gamma \sum_{y \in S} P(s,a,y)V^*(y) \big],$$ where:
#
# *   $r(s, a)$ is the reward obtained from taking action $a$ in state $s$,
# *   $P(s, a, y)$ is the probability of reaching state $y$ when taking action
#     $a$ in state $s$,
# *   $\gamma \in [0,1]$ is a discount factor defining the relative importance
#     of long term rewards over short term ones (the closer to 0, the more the
#     agent focuses on immediate rewards).
#
#
#
# > Si γ est petit, on va preferer une recompense (reward) plus tard
#
#
#
# In practice, we start with an initial value function $V^0$ (for instance, the
# values of all states are 0), and then we iterate for all states $s$
# $$V^{i+1}(s) = \max_a \big[ r(s,a) + \gamma \sum_{y \in S} P(s,a,y)V^i(y)
# \big],$$
#
# until the values converge, that is $\forall s, V^{i+1}(s) \approx V^i(s)$. It
# is shown that at convergence, $\forall s, V^i(s)= V^*(s)$.
#
# To visualize the policy obtained from **value iteration**, we need to first
# define the `get_policy_from_V()` function

# %%
def get_policy_from_v(mdp: MazeMDPEnv, v: np.ndarray) -> np.ndarray:
    """Outputs a policy given the state values"""

    # Sets initial state values are set to 0
    policy = np.zeros(mdp.nb_states)

    # Loop over MDP states
    for x in range(mdp.nb_states):
        if x in mdp.terminal_states:
            # Takes the reward associated with the terminal state
            policy[x] = np.argmax(mdp.r[x, :])
        else:
            # Compute the value V(x) for state x
            v_temp = []

            # Loop over actions
            for u in range(mdp.action_space.n):
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):
                    summ = summ + mdp.P[x, u, y] * v[y]
                v_temp.append(mdp.r[x, u] + mdp.gamma * summ)
            policy[x] = np.argmax(v_temp)
    return policy

# %% [markdown]
# The `value_iteration_v(mdp)` function below provides the code of **value
# iteration** using the $V$ function. It is given as an example from which you
# can derive other instances of dynamic programming algorithms. Look at it more
# closely, this will help for later questions:
#
# * you can ignore the `mdp.new_render()` and `mdp.render(...)` functions which
#   are here to provide the visualization of the iterations.
# * find in the code the loop over states, the main loop that performs these
#   updates until the values don't change significantly anymore, the main update
#   equation. Found them? OK, you can continue...

# %% [markdown]
# # TO BE NOTED
# ## Here is how it works the following code
#
# We take the environment and w ewant to apply the value itteration methode. For that we need to calculate all the values for all the states by taking into account all the actions.
#
# In order to do that, we need to initialise the values of every state to zero. This is what is achieved with:
#
#
# ```
# v = np.zeros(mdp.nb_states)  # initial state values are set to 0
# ```
#
#
#
# > We are constantly calculating the v values until there are very small changes (the difference is smaller than 0.01). This is why we need to make sure that the loop while is not stopped (continuing updating the v values) unless this condition is met. **This is the condition (1)**
#
#
#
# So, for every state, we calculate its value and we save it in a local copy of the v_values. This is what is achieved with:
#
#
#
# ```
# v_old = v.copy()
# ```
#
# In order to calculate the v value of a state we are using the formula provided at the **Value iteration with the V function part**. If a state is the final one, then we assign to it the greater value of r.
#
# For all the others we are doing the calculation.
#
# ## Conclusion
#
# > We also save a list of all the V_values that were calculated before arriving at a V_values vector that respects the condition (1) that is used for visualisations porpuses.
#
# We find the optimal policy be using the get_policy_from_v that is defined above whose logic is similar to the one used to calculate the different values of the different states.

# %%
def value_iteration_v(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    # Value Iteration using the state value v
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    v_list = []
    stop = False

    mdp.init_draw("Value iteration V")

    mdp.draw_v(v)

    while not stop:
        v_old = v.copy()
        mdp.draw_v(v)

        for x in range(mdp.nb_states):  # for each state x
            # Compute the value of the state x for each action u of the MDP action space
            if x in mdp.terminal_states:
                v[x] = np.max(mdp.r[x, :])
            else:
                v_temp = []
                for u in range(mdp.action_space.n):
                    # Process sum of the values of the neighbouring states
                    summ = 0
                    for y in range(mdp.nb_states):
                        summ = summ + mdp.P[x, u, y] * v_old[y]
                    v_temp.append(mdp.r[x, u] + mdp.gamma * summ)

                # Select the highest state value among those computed
                v[x] = np.max(v_temp)

        # Test if convergence has been reached
        if (np.linalg.norm(v - v_old)) < 0.01:
            stop = True
        v_list.append(np.linalg.norm(v))

    policy = get_policy_from_v(mdp, v)
    mdp.draw_v_pi(v, policy)
    return v, v_list

# %% [markdown]
# Let us run it on the previously defined MDP

# %%
v, v_list = value_iteration_v(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[ 0,  4,  8, 11, 15],
#        [ 1,  5, -1, 12, 16],
#        [ 2,  6, -1, …

# %% [markdown]
# ### Value iteration with the $Q$ function ###
#
# The state-action value function $Q^{\pi}(s,a)$ defines the value of being in
# state $s$, taking action $a$ then following policy $\pi$. The Bellman
# Optimality Equation for $Q^*$ is $$ Q^*(s,a) =  r(s,a) + \gamma \sum_{y}
# P(s,a,y) \max_{a'}Q^*(y,a'). $$
#
# **Question:** By taking inspiration from the `value_iteration_v(mdp)` function
# above, fill the blank (given with '\#Q[x,u]=...') in the code of
# `value_iteration_q(mdp)`.
#
# # TO BE NOTED
#
# V(s) = max[Q(s,a)]
#
#
# > Q is a matrix (rows are states and columns are actions) which actually allows us to have the result for a state of all possible actions from this state.

# %%
# ------------------ Value Iteration with the Q function ---------------------#
# Given a MDP, this algorithm computes the optimal action value function Q
# It then derives the optimal policy based on this function


def value_iteration_q(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    q_list = []
    stop = False

    mdp.init_draw("Value iteration Q")

    mdp.draw_v(q)

    while not stop:
        qold = q.copy()

        mdp.draw_v(q)

        for x in range(mdp.nb_states):
            for u in range(mdp.action_space.n):
                if x in mdp.terminal_states:
                    q[x, u] = mdp.r[x, u]
                else:
                    summ = 0
                    for y in range(mdp.nb_states):
                        summ += mdp.P[x, u, y] * np.max(qold[y, :])

                    # Compléter d'après la formule ci-dessus
                    q[x, u] = mdp.r[x, u] + mdp.gamma * summ # It is doing that for every state. It is completing the Q matrix
                    # assert False, 'Not implemented yet'


        if (np.linalg.norm(q - qold)) <= 0.01:
            stop = True
        q_list.append(np.linalg.norm(q))

    mdp.draw_v(q)

    return q, q_list

# %% [markdown]
# Once you are done, run it.

# %%
q, q_list = value_iteration_q(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[ 0,  4,  8, 11, 15],
#        [ 1,  5, -1, 12, 16],
#        [ 2,  6, -1, …

# %% [markdown]
# ---
#
#
#
# ## Policy Iteration ##
#
# The **policy iteration** algorithm is more complicated than **value
# iteration**. Given a MDP and a policy $\pi$, **policy iteration** iterates the
# following steps:
#
# *   Evaluate policy $\pi$: compute $V$ or $Q$ based on the policy $\pi$;
# *   Improve policy $\pi$: compute a better policy based on $V$ or $Q$.
#
# **This process is repeated until convergence, i.e. when the policy cannot be
# improved anymore.**
#
# ### Policy iteration with the $V$ function ###
#
# When using $V$, $V^{\pi}(s)$ is the expected return when starting from state
# $s$ and following policy $\pi$. It is processed based on the Bellman
# Optimality Equation for deterministic policies:
#
# $$V^\pi(s) = r(s, \pi(s)) + \gamma \sum_{y \in S}P(s, \pi(s), y)V^\pi(y),$$
#
# where:
#
# *   $\pi$ is a deterministic policy, meaning that in a state $s$, the agent
#     always selects the same action,
# *   $V^\pi(y)$ is the value of the state $y$ under policy $\pi$.
#
# Thus, given a policy $\pi$, one must first compute its value function
# $V^\pi(s)$ for all states $s$ iterating the Bellman Optimality Equation until
# convergence, that is using **value iteration**. Then, one must determine if
# policy $\pi$ can be improved based on $V$. For that, in each state $s$, one
# can compute the Q-value $Q(s,a)$ of applying action $a$ and then following
# policy $\pi$ based on the just computed $V^\pi$, and replace the action
# $\pi(s)$ with $\arg\max_a Q(s,a)$.
#
# In order to facilitate the coding of **policy iteration** algorithms, we first
# define a set of useful functions.
#
# The `improve_policy_from_v(mdp, v, policy)` function is very similar to the
# `get_policy_from_v(v)` function which was given above. The main difference is
# that it takes a policy as argument and improves this policy when possible,
# thus is more in the spirit of the `policy improvement` step of **policy
# iteration**. But both functions can be used interchangeably.
#
# The functions `evaluate_one_step_v(mdp, v, policy)`, where `mdp` is a given
# MDP, `v` is some value function in this MDP and `policy` is some policy and
# the function `evaluate_v(mdp, policy)` are also given. These functions are
# used to build the value function $V^\pi$ corresponding to policy $\pi$.

# %%
def improve_policy_from_v(
    mdp: MazeMDPEnv, v: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Improves a policy given the state values
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        if x in mdp.terminal_states:
            policy[x] = np.argmax(mdp.r[x, :])
        else:
            v_temp = np.zeros(mdp.action_space.n)
            for u in range(mdp.action_space.n):
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):
                    summ = summ + mdp.P[x, u, y] * v[y]
                v_temp[u] = mdp.r[x, u] + mdp.gamma * summ

            # for all the policies that were saved (which are equal to number of actions). Meaning that we have the same number of policies as actions
            for u in range(mdp.action_space.n):
                if v_temp[u] > v_temp[policy[x]]:
                    policy[x] = u
    return policy

# %%
def evaluate_one_step_v(
    mdp: MazeMDPEnv, v: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Outputs the state value function after one step of policy evaluation
    # Corresponds to one application of the Bellman Operator
    v_new = np.zeros(mdp.nb_states)  # initial state values are set to 0
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        if x in mdp.terminal_states:
            v_new[x] = mdp.r[x, policy[x]]
        else:
            # Process sum of the values of the neighbouring states
            summ = 0
            for y in range(mdp.nb_states):
                summ = summ + mdp.P[x, policy[x], y] * v[y]
            v_new[x] = mdp.r[x, policy[x]] + mdp.gamma * summ
    return v_new

# %% [markdown]
# # TO BE NOTED
#
# For a given policy, we receive the the v values for the different states and we check if the condition (1) is respected.
#
# The evaluate_one_step_v is using the logic found at value_iteration_v above.

# %%
def evaluate_v(mdp: MazeMDPEnv, policy: np.ndarray) -> np.ndarray:
    # Outputs the state value function of a policy
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    stop = False
    while not stop:
        vold = v.copy()

        # For the given
        v = evaluate_one_step_v(mdp, vold, policy)

        # Test if convergence has been reached
        if (np.linalg.norm(v - vold)) < 0.01:
            stop = True
    return v

# %% [markdown]
# To perform **policy iteration** we also need an initial random policy.

# %%
from mazemdp import random_policy

# %% [markdown]
# ---
#
#
#
# **Question:** By using the above functions, fill the code of the `policy_iteration_v(mdp)` function below.

# %%
# ---------------- Policy Iteration with the V function -----------------#
# Given an MDP, this algorithm simultaneously computes
# the optimal state value function V and the optimal policy


def policy_iteration_v(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    # policy iteration over the v function
    v = np.zeros(mdp.nb_states)  # initial state values are set to 0
    v_list = []
    policy = random_policy(mdp)

    stop = False

    mdp.init_draw("Policy Iteration (V)")

    while not stop:
        vold = v.copy()

        mdp.draw_v(v, title="Policy iteration Q")

        # Step 1 : Policy Evaluation
        # To be completed...

        v = evaluate_v(mdp, policy) #policy[i] c'est l'action prise à l'état i
        # assert False, 'Not implemented yet'


        # Step 2 : Policy Improvement
        # To be completed...

        policy = improve_policy_from_v(mdp, v, policy) #met à jour la policy en fonction de v (qui est lui même calculé en fonction de la policy)
        # assert False, 'Not implemented yet'


        # Check convergence
        if (np.linalg.norm(v - vold)) < 0.01:
            stop = True
        v_list.append(np.linalg.norm(v))

    mdp.draw_v_pi(v, get_policy_from_v(mdp, v))

    return v, v_list

# %% [markdown]
# And finally run it.

# %%
v, v_list = policy_iteration_v(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[ 0,  4,  8, 11, 15],
#        [ 1,  5, -1, 12, 16],
#        [ 2,  6, -1, …

# %% [markdown]
# # TO BE NOTED
#
# ## The logic
#
# Here we are receiving a random policy by using the mazemdp library. Before to evaluate_v we were findign the differnt v values and finally we were using the functin get_policy_from_v in. order to get an optimal policy for the different V values.
#
# In this scenario, we take a random policy and we receive the different v values according to that policy (not generic as we did on value_iteration_v). Then we want to see if there is a better a policy if the condition (1) is NOT respected. So we are trying to improve it by using the improve_policy_from_v given the state values calculated before. In terms of code, now the new policy that was calculated is applied to calculate the new V values and we continue to do that until the condition (1) is respected.
#
# ## Remarks
#
# 1.   The main goal here for this method of resolution is to explore the different possibilities before choosing th emost optimal one. With that being said a random policy ensure the exploration of the state-action space.
# 2.   Moreover, when we were using get_policy_from_v, the policy was taking into account only a choice. It wasn't examining all the other policies that could be obtained.
#
# To conclude, this method where we find an initial policy and then we try to improve it, is an efficient approach when the envrionment is complex meaning that potentially the reward function is sparse.
#
# On the other hand, value_iteration_v could potentially be more efficient when the rewards are more dense.
#
# **More comparison details can be found on the final explanation at the part Explanation in the end of the notebook.**
#
#
#
# ---

# %% [markdown]
# ### Policy iteration with the $Q$ function ###
#
# The **policy iteration** algorithm with the $Q$ function is the same as with
# the $V$ function, but the policy improvement step is more straightforward.
#
# When using $Q$, the Bellman Optimality Equation with deterministic policy
# $\pi$ for $Q$ becomes: $$Q^{\pi}(s,a) = r(s,a) + \gamma \sum_{y \in
# S}P(s,a,y)Q^{\pi}(y,\pi(y)).$$
#
# The policy can then be updated as follows: $$\pi^{(t+1)}(s) =
# \arg\max_aQ^{\pi^{(t)}}(s,a).$$
#
# First, we need to determine a policy from the $Q$ function.
#
# **Question:**  fill the `get_policy_from_q(q)` function, where $q$ is the
# state-action value function.

# %%
def get_policy_from_q(q: np.ndarray) -> np.ndarray:
    # Outputs a policy given the action values

    policy = np.argmax(q, axis=1)

    return policy
    # assert False, 'Not implemented yet'

# %% [markdown]
# # TO BE NOTED
#
# In order to receive a policy from a q (state-action value) we need to inialise a policy object and complete it (evaluate it) according to the different actions that exist.
#
#
#
# ---

# %% [markdown]
# **Question:** By drawing inspiration on the functions give with the $v$
# function, fill the code of the `evaluate_one_step_q(mdp, q, policy)` function
# below, where $q$ is some action value function, and the `evaluate_q(mdp,
# policy)` function.

# %%
def evaluate_one_step_q(
    mdp: MazeMDPEnv, q: np.ndarray, policy: np.ndarray
) -> np.ndarray:
    # Outputs the state value function after one step of policy evaluation
    qnew = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    for x in range(mdp.nb_states):  # for each state x
        # Compute the value of the state x for each action u of the MDP action space
        for u in range(mdp.action_space.n):
            if x in mdp.terminal_states:
                qnew[x, u] = mdp.r[x, u]
            else:
                # Process sum of the values of the neighbouring states
                summ = 0
                for y in range(mdp.nb_states):

                    summ += mdp.P[x, u, y] * q[y, policy[y]] # according to the formula provided we have: the sum of [probability * q]
                    # assert False, 'Not implemented yet'


                qnew[x, u] = mdp.r[x, u] + mdp.gamma * summ # this sum is multiplied by γ and we add the reward function to the logic according to formula foudn at Policy iteration with Q function part
                # assert False, 'Not implemented yet'

    return qnew

# %%
def evaluate_q(mdp: MazeMDPEnv, policy: np.ndarray) -> np.ndarray:
    # Outputs the state value function of a policy
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    stop = False
    while not stop:
        qold = q.copy()

        # We are receiving state-value according to a policy

        q = evaluate_one_step_q(mdp, qold, policy)
        # assert False, 'Not implemented yet'


        # Test if convergence has been reached
        if (np.linalg.norm(q - qold)) < 0.01:
            stop = True
    return q

# %% [markdown]
# **Question:** By using the above functions, fill the code of the `policy_iteration_q(mdp)` function below.

# %%
# ---------------- Policy Iteration with the Q function -----------------#
# Given a MDP, this algorithm simultaneously computes
# the optimal action value function Q and the optimal policy


def policy_iteration_q(
    mdp: MazeMDPEnv, render: bool = True
) -> Tuple[np.ndarray, List[float]]:
    """policy iteration over the q function."""
    q = np.zeros(
        (mdp.nb_states, mdp.action_space.n)
    )  # initial action values are set to 0
    q_list = []
    policy = random_policy(mdp)

    stop = False

    mdp.init_draw("Policy iteration Q")

    while not stop:
        qold = q.copy()
        mdp.draw_v(q)

        # Step 1 : Policy evaluation

        q = evaluate_q(mdp, policy) # we are calculating the q according to a random policy
        # assert False, 'Not implemented yet'


        # Step 2 : Policy improvement

        policy = get_policy_from_q(q) # based on the results, we improve the policy
        # assert False, 'Not implemented yet'


        # Check convergence
        if (np.linalg.norm(q - qold)) <= 0.01: # here we make sure that the condition (1) is respected
            stop = True
        q_list.append(np.linalg.norm(q))

    mdp.draw_v_pi(q, get_policy_from_q(q))
    return q, q_list

# %% [markdown]
# Finally, run it.

# %%
q, q_list = policy_iteration_q(env, render=True)
# Out:
# VBox(children=(MazeWidget(cells=array([[ 0,  4,  8, 11, 15],
#        [ 1,  5, -1, 12, 16],
#        [ 2,  6, -1, …

# %% [markdown]
# # TO BE NOTED
#
# Policy iteration starts with a random policy as seen before with the V scenario. The idea as always is to explore if the policy is optimal or not.
#
# Unlike value iteration, which directly computes the optimal value function, policy iteration iteratively improves the policy based on the current v value.
#
# **Whether we use directly the value_iteration_q or policy_iteration_q depends on the complexity of the environment.**
#
#
#
# > The method where we find an initial policy and then we try to improve it, is an efficient approach when the envrionment is complex meaning that potentially the reward function is sparse [as previously noted]
#
#
#
# ---

# %% [markdown]
# ### Experimental comparisons
#
# We now compare the efficiency of the various dynamic programming methods using either the $V$ or the  $Q$ functions.
#
# In all your dymanic programming functions, add code to count the number of iterations and the number of elementary $V$ or $Q$ updates. Use the provided `mazemdp.Chrono` class to measure the time taken. You may generate various mazes of various sizes to figure out the influence of the maze topology.
#
# Build a table where you compare the various dymanic programming functions in terms of iterations, elementary operations and time taken.
#
# You can run the `plot_convergence_vi_pi(...)` function provided below to visualize the convergence of the various algorithms.

# %%
# ---- plot learning curves of Q-Learning and Sarsa using epsilon-greedy and softmax -----#


def plot_convergence_vi_pi(m, render):
    v, v_list1 = value_iteration_v(m, render)
    q, q_list1 = value_iteration_q(m, render)
    v, v_list2 = policy_iteration_v(m, render)
    q, q_list2 = policy_iteration_q(m, render)

    plt.plot(range(len(v_list1)), v_list1, label="value_iteration_v")
    plt.plot(range(len(q_list1)), q_list1, label="value_iteration_q")
    plt.plot(range(len(v_list2)), v_list2, label="policy_iteration_v")
    plt.plot(range(len(q_list2)), q_list2, label="policy_iteration_q")

    plt.xlabel("Number of episodes")
    plt.ylabel("Norm of V or Q value")
    plt.legend(loc="upper right")
    # plt.savefig("comparison_DP.png")
    plt.title("Comparison of convergence rates")
    plt.show()

# %% [markdown]
# ---
#
#
#
# **Question:** Run the code below and visualize the results of the different algorithms

# %%
plot_convergence_vi_pi(env, False)
# Out:
# VBox(children=(MazeWidget(cells=array([[ 0,  4,  8, 11, 15],
#        [ 1,  5, -1, 12, 16],
#        [ 2,  6, -1, …

# %% [markdown]
# # EXPLANATION
#
# If we maintain the same convergence condition (i.e., changes smaller than 0.01), we observe that both policy iteration methods are more efficient, as they converge more quickly compared to the value iteration algorithms (based on the number of episodes).
#
# When comparing the two functions, V and Q, we notice that in both cases they converge to a specific value. However, in our analysis, we are only concerned with the fact that both functions converge, rather than the actual values to which they converge.
#
# For this reason, our primary focus is on the speed of convergence to the "final" norm. The choice of function does not impact the result. So using the policy_iteration method seems to be better than the value_iteration method.
#
#
#
# > To be noted that if we change the condition of the policy_iteration methods to a number that is even smaller like 0.001, then we will observe that the numbe rof episodes until converging is bigger than the one we have right now which is what we are expecting.
